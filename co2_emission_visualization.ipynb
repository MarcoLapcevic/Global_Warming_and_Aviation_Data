# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.max_rows
# Out:
# 60

# %%
co2_emissions_dataset = pd.read_csv('CO2_Emission.csv')

# %%
co2_emissions_dataset = co2_emissions_dataset.iloc[-44:]
co2_emissions_dataset.head()
# Out:
#     country  year  iso_code    population           gdp  cement_co2  \
# 230   World  1980       NaN  4.447606e+09  3.198261e+13     406.269
# 231   World  1981       NaN  4.528777e+09           NaN     406.283
# 232   World  1982       NaN  4.612673e+09           NaN     404.280
# 233   World  1983       NaN  4.697328e+09           NaN     413.445
# 234   World  1984       NaN  4.782176e+09           NaN     421.227
#
#      cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 230                  0.091  19488.523        -120.496           -0.614  ...
# 231                  0.090  19022.902        -465.621           -2.389  ...
# 232                  0.088  18871.098        -151.806           -0.798  ...
# 233                  0.088  18991.910         120.814            0.640  ...
# 234                  0.088  19647.801         655.890            3.454  ...
#
#      share_global_other_co2  share_of_temperature_change_from_ghg  \
# 230                     NaN                                 100.0
# 231                     NaN                                 100.0
# 232                     NaN                                 100.0
# 233                     NaN                                 100.0
# 234                     NaN                                 100.0
#
#      temperature_change_from_ch4  temperature_change_from_co2  \
# 230                        0.243                        0.534
# 231                        0.248                        0.545
# 232                        0.252                        0.555
# 233                        0.257                        0.566
# 234                        0.261                        0.577
#
#      temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 230                        0.814                        0.037  33347.820
# 231                        0.830                        0.037  32570.309
# 232                        0.846                        0.038  32320.344
# 233                        0.862                        0.039  32752.469
# 234                        0.878                        0.040  34383.637
#
#      total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 230                 23662.867        NaN              NaN
# 231                 23079.902        NaN              NaN
# 232                 23016.582        NaN              NaN
# 233                 23197.736        NaN              NaN
# 234                 23955.510        NaN              NaN
#
# [5 rows x 79 columns]

# %%
plt.figure(figsize=(6, 4))
plt.xlabel("Time (Years)", fontname='Times New Roman',
           fontsize=12)
plt.ylabel("Annual CO₂ emissions (in million metric tons)", fontname='Times New Roman',
           fontsize=12)
plt.title("CO₂ emissions per year", fontname='Monospace',
          fontsize=18)

plt.plot(co2_emissions_dataset['year'], co2_emissions_dataset['co2'])
